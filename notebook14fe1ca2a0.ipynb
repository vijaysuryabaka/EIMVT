# %% [markdown]
# **Defining the objective**

# %% [markdown]
# The aim of this project is to create a Speech-To-Text application using an ASR (Automatic Speech Recognition) system, Whisper.

# %% [markdown]
# Whisper has been trained for 680,000 hours on huge amount of speech data collected from the internet. The diverse dataset allows Whisper to understand different accents, and filter background noise. The Whisper architecture is a simple end-to-end approach, implemented as an encoder-decoder Transformer. Input audio is split into 30-second chunks, converted into a log-Mel spectrogram, and then passed into an encoder. A decoder is trained to predict the corresponding text caption, intermixed with special tokens that direct the single model to perform tasks such as language identification, phrase-level timestamps, multilingual speech transcription, and to-English speech translation.
#
#  You can learn more about Whisper from https://openai.com/blog/whisper/

# %% [markdown]
# **Installing Required Libraries**

# %%
# !pip install --upgrade torch
# !pip install pytube
# !pip install git+https://github.com/openai/whisper.git
# !pip install git+https://github.com/librosa/librosa
# !pip install matplotlib
# Out:
# Requirement already satisfied: torch in d:\unisys\.venv\lib\site-packages (2.2.0)
# Requirement already satisfied: filelock in d:\unisys\.venv\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\unisys\.venv\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in d:\unisys\.venv\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in d:\unisys\.venv\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in d:\unisys\.venv\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in d:\unisys\.venv\lib\site-packages (from torch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\unisys\.venv\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in d:\unisys\.venv\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pytube in d:\unisys\.venv\lib\site-packages (15.0.0)
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to c:\users\shara\appdata\local\temp\pip-req-build-mpuoxp2h
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numba in d:\unisys\.venv\lib\site-packages (from openai-whisper==20231117) (0.59.0)
# Requirement already satisfied: numpy in d:\unisys\.venv\lib\site-packages (from openai-whisper==20231117) (1.26.4)
# Requirement already satisfied: torch in d:\unisys\.venv\lib\site-packages (from openai-whisper==20231117) (2.2.0)
# Requirement already satisfied: tqdm in d:\unisys\.venv\lib\site-packages (from openai-whisper==20231117) (4.66.2)
# Requirement already satisfied: more-itertools in d:\unisys\.venv\lib\site-packages (from openai-whisper==20231117) (10.2.0)
# Requirement already satisfied: tiktoken in d:\unisys\.venv\lib\site-packages (from openai-whisper==20231117) (0.6.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\unisys\.venv\lib\site-packages (from numba->openai-whisper==20231117) (0.42.0)
# Requirement already satisfied: regex>=2022.1.18 in d:\unisys\.venv\lib\site-packages (from tiktoken->openai-whisper==20231117) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in d:\unisys\.venv\lib\site-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: filelock in d:\unisys\.venv\lib\site-packages (from torch->openai-whisper==20231117) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\unisys\.venv\lib\site-packages (from torch->openai-whisper==20231117) (4.9.0)
# Requirement already satisfied: sympy in d:\unisys\.venv\lib\site-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in d:\unisys\.venv\lib\site-packages (from torch->openai-whisper==20231117) (3.2.1)
# Requirement already satisfied: jinja2 in d:\unisys\.venv\lib\site-packages (from torch->openai-whisper==20231117) (3.1.3)
# Requirement already satisfied: fsspec in d:\unisys\.venv\lib\site-packages (from torch->openai-whisper==20231117) (2024.2.0)
# Requirement already satisfied: colorama in d:\unisys\.venv\lib\site-packages (from tqdm->openai-whisper==20231117) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\unisys\.venv\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\unisys\.venv\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\unisys\.venv\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\unisys\.venv\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\unisys\.venv\lib\site-packages (from jinja2->torch->openai-whisper==20231117) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in d:\unisys\.venv\lib\site-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git 'C:\Users\shara\AppData\Local\Temp\pip-req-build-mpuoxp2h'
# Collecting git+https://github.com/librosa/librosa
#   Cloning https://github.com/librosa/librosa to c:\users\shara\appdata\local\temp\pip-req-build-owz41ngl
#   Resolved https://github.com/librosa/librosa to commit 8dae20c66353190749486abf6b332d93c4ab2b46
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: audioread>=2.1.9 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (1.4.0)
# Requirement already satisfied: joblib>=0.14 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (0.3)
# Requirement already satisfied: msgpack>=1.0 in d:\unisys\.venv\lib\site-packages (from librosa==0.10.1) (1.0.7)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\unisys\.venv\lib\site-packages (from numba>=0.51.0->librosa==0.10.1) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in d:\unisys\.venv\lib\site-packages (from pooch>=1.0->librosa==0.10.1) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\unisys\.venv\lib\site-packages (from pooch>=1.0->librosa==0.10.1) (23.2)
# Requirement already satisfied: requests>=2.19.0 in d:\unisys\.venv\lib\site-packages (from pooch>=1.0->librosa==0.10.1) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\unisys\.venv\lib\site-packages (from scikit-learn>=0.20.0->librosa==0.10.1) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in d:\unisys\.venv\lib\site-packages (from soundfile>=0.12.1->librosa==0.10.1) (1.16.0)
# Requirement already satisfied: pycparser in d:\unisys\.venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.1) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\unisys\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\unisys\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\unisys\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\unisys\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (2024.2.2)
#   Running command git clone --filter=blob:none --quiet https://github.com/librosa/librosa 'C:\Users\shara\AppData\Local\Temp\pip-req-build-owz41ngl'
#   Running command git submodule update --init --recursive -q
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.48.1-cp310-cp310-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.2 kB ? eta -:--:--
#      ------------------- ------------------- 81.9/162.2 kB 2.2 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/162.2 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 162.2/162.2 kB 1.2 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in d:\unisys\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\unisys\.venv\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\unisys\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\unisys\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp310-cp310-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.6 MB 4.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.6 MB 3.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/7.6 MB 3.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.6 MB 3.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.6 MB 3.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.6 MB 3.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.6 MB 3.3 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/7.6 MB 3.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.6 MB 3.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/7.6 MB 3.3 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.6 MB 3.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.6 MB 3.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.6 MB 3.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.2/7.6 MB 3.5 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.6 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.6 MB 3.5 MB/s eta 0:00:02
#    -------------- ------------------------- 2.8/7.6 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.6 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/7.6 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.6 MB 4.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.0/7.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.3/7.6 MB 4.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.6 MB 4.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.2/7.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.4/7.6 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 5.7/7.6 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.2/7.6 MB 5.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.9/7.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 5.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
#    ---------------------------------------- 0.0/186.7 kB ? eta -:--:--
#    --------------------------------------- 186.7/186.7 kB 11.0 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.48.1-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 17.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.2 MB 15.0 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.2 MB 7.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.2 MB 6.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.4/2.2 MB 6.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.2 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.2 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------- ----------------------------- 0.7/2.6 MB 20.8 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.6 MB 10.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 11.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 12.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 8.0 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.48.1 kiwisolver-1.4.5 matplotlib-3.8.2 pillow-10.2.0 pyparsing-3.1.1

# %%
#Importing the necessary libraries
import torch
import whisper
import pytube
import librosa
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

# %% [markdown]
# **Please note:** If you don't already have those libraries installed, trying to import them would not work as they have to be installed first.

# %% [markdown]
# **Loading the Model**

# %% [markdown]
# There are five model sizes to choose from, four have English-only versions, offering speed and accuracy trade-offs. The model sizes are:
# - tiny: 39M Parameters, English-only model (tiny.en), Multilingual model (tiny), Required VRAM (1GB), Relative speed (32x)
# - base: 74M Parameters, English-only model (base.en), Multilingual model (base), Required VRAM (1GB), Relative speed (16x)
# - small: 244M Parameters, English-only model (small.en), Multilingual model (small), Required VRAM (2GB), Relative speed (6x)
# - medium: 769M Parameters, English-only model (medium.en), Multilingual model (medium), Required VRAM (5GB), Relative speed (2x)
# - tiny: 1550M Parameters, English-only model (N/A), Multilingual model (large), Required VRAM (10GB), Relative speed (1x)
# The tiny model can be utilized best for light weight applications, the large model if accuracy is most important, and the base, small or medium models for everything in between. For this project, we would be using the medium model.

# %%
model_m = whisper.load_model('medium')

# %% [markdown]
# **Loading the file**

# %% [markdown]
# We start by loading an audio file.

# %%
file_path = 'D:/Unisys/WhatsApp Audio 2024-02-14 at 14.31.13_cc7d5515.dat.mp3'

# %% [markdown]
# I created a custom voice recording of myself, in file_path above to use for this project. Next we're going to load the audio file in file_path using the load_audio() function.

# %%
#Loading
audio_13 = whisper.load_audio(file_path)
audio_13
# Out:
# array([0.        , 0.        , 0.        , ..., 0.01187134, 0.01794434,
#        0.046875  ], dtype=float32)

# %% [markdown]
# Next, we find the sampling interval. The sampling interval is the distance or time between the measurements. The total time of audio is 13 seconds.

# %%
T = 13

# %%
#Checking the number of samples in our audio file
n_samples =  audio_13.shape[0]
n_samples
# Out:
# 107520

# %% [markdown]
# There are 200448 number of samples in 13 seconds audio. Now we find the time between samples.

# %%
#Time between samples
delta = T/n_samples
delta
# Out:
# 0.0001209077380952381

# %% [markdown]
# The time between samples is 6.485472541507024e-05. Next, we find the sampling frequency.

# %%
#Sampling frequency
Fs = 1/delta
Fs
# Out:
# 8270.76923076923

# %% [markdown]
# The sampling frequency is 15419.076923076924. Next, we find the time of each sample.

# %%
#Time of each sample
time = np.linspace(0,(n_samples-1) * delta,n_samples)
time
# Out:
# array([0.00000000e+00, 1.20907738e-04, 2.41815476e-04, ...,
#        1.29996373e+01, 1.29997582e+01, 1.29998791e+01])

# %% [markdown]
# Now we plot the amplitude with respect to time:

# %%
plt.figure(figsize=(20,10))
plt.title('Signal')
plt.plot(time,audio_13)
plt.ylabel('amplitude')
plt.xlabel('seconds')
plt.show()

# %% [markdown]
# Above is a waveform for the signal. Now, we can use the pad_or_trim() method to ensure the sample is in the right form for inference.

# %%
audio = whisper.pad_or_trim(audio_13)

# %% [markdown]
# Next, we plot the amplitude with respect to time with trimmed/padded audio.

# %%
#Number of samples in our trimmed/padded audio
n_samples =  audio.shape[-1]
#Time of each sample
time = np.linspace(0,(n_samples-1)*delta,n_samples)

# %%
plt.figure(figsize=(20,10))
plt.title('Signal')
plt.plot(time,audio)
plt.ylabel('amplitude')
plt.xlabel('seconds')
plt.show()

# %% [markdown]
# Next, we can start plotting a mel spectogram by applying a log_mel_spectogram() funtion to our audio file. It converts the y-axis (frequency) into the mel scale:

# %%
mel = whisper.log_mel_spectrogram(audio).to(model_m.device)

# %% [markdown]
# The output above is a tensor of converted frequencies. Now, we plot 2 subplots, one is a regular representation of sound amplitude over period of time, and the other is our mel spectrogram:

# %%
fig, (ax1, ax2) = plt.subplots(2)
fig.tight_layout(pad=5.0)
ax1.plot(time,audio)
ax1.set_title('Signal')
ax1.set_xlabel('Time, seconds')
ax1.set_ylabel('Amplitude')
ax2.imshow((mel.numpy()*mel.numpy())**(1/2),interpolation='nearest', aspect='auto')
ax2.set_title('Mel Spectrogram of a Signal')
ax2.set_xlabel('Time, seconds')
ax2.set_ylabel('Mel Scale')
# Out:
# Text(42.722222222222214, 0.5, 'Mel Scale')

# %% [markdown]
# Next, we can move on to language detection.

# %% [markdown]
# **Language detection**

# %% [markdown]
# We will listen to our audio file and detect the spoken language. The sample rate (sr) by default is 22050, which means that for every second there are 22,050 samples. We can use ipd.Audio() function to listen to our audio file.

# %%
sr=22050
ipd.Audio(audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Next, We can obntain the probability of each language by using detect_language() method.

# %%
probs = model_m.detect_language(mel)

# %%
probs
# Out:
# (tensor(50287),
#  {'kk': 1.3835561674113706e-07,
#   'vi': 9.708070138003677e-05,
#   'cs': 1.4901805798217538e-06,
#   'et': 4.159894160693511e-06,
#   'tk': 1.2384499648021574e-08,
#   'ps': 1.8737500795396045e-05,
#   'te': 0.003228211309760809,
#   'nn': 0.0017195401014760137,
#   'ka': 1.1993919191155555e-09,
#   'gu': 5.516450869436085e-07,
#   'hu': 1.5622202909071348e-06,
#   'ja': 0.0016791303642094135,
#   'en': 0.0048768664710223675,
#   'az': 1.985004018933978e-07,
#   'zh': 0.0008606736664660275,
#   'ne': 1.7518083041068166e-05,
#   'lb': 2.1936039651393457e-09,
#   'ms': 0.0014415137702599168,
#   'tt': 1.8666155288116215e-09,
#   'ba': 9.704773873409067e-09,
#   'el': 8.049301686696708e-05,
#   'ha': 2.1842447850417557e-08,
#   'la': 0.0003857725823763758,
#   'lt': 1.3350512745091692e-05,
#   'am': 6.109471684112577e-08,
#   'haw': 6.38099227217026e-05,
#   'sr': 2.910510659148713e-07,
#   'lo': 7.368716410383058e-07,
#   'mg': 1.1360603124899171e-08,
#   'ca': 1.641996277612634e-06,
#   'as': 2.419611533355237e-08,
#   'af': 2.1908404960413463e-05,
#   'th': 4.2428488086443394e-05,
#   'mr': 3.8133744055812713e-06,
#   'yi': 9.05869370626533e-08,
#   'sq': 2.3037726393226876e-08,
#   'mn': 9.381476957059931e-06,
#   'kn': 0.00015147784142754972,
#   'bg': 4.359664217190584e-06,
#   'sd': 3.0763246741116745e-06,
#   'sk': 9.352774554827192e-08,
#   'be': 2.311498406015744e-07,
#   'mk': 6.309117228653349e-09,
#   'sa': 0.0008165388135239482,
#   'de': 0.00012809570762328804,
#   'fa': 1.0620838111208286e-05,
#   'tr': 0.0007389488164335489,
#   'fr': 6.840845890110359e-05,
#   'tg': 3.7156866472543015e-09,
#   'no': 1.8983257632498862e-06,
#   'my': 1.0924625257757725e-06,
#   'da': 1.6807074416647083e-06,
#   'br': 5.526005224965047e-06,
#   'id': 0.00021173861750867218,
#   'so': 9.676013768000757e-09,
#   'ht': 6.550907016844576e-08,
#   'pl': 0.00020422058878466487,
#   'ur': 0.0004483361553866416,
#   'pa': 2.5162021302094217e-06,
#   'it': 0.0001232509530382231,
#   'ru': 0.0005208027432672679,
#   'pt': 5.818177305627614e-05,
#   'su': 4.219486982037779e-08,
#   'nl': 5.930249244556762e-05,
#   'mt': 1.8601552298491697e-08,
#   'sn': 2.9554339562309906e-05,
#   'sv': 6.107357421569759e-06,
#   'bn': 1.3473481885739602e-05,
#   'is': 4.544467174127931e-06,
#   'cy': 0.0002080797275993973,
#   'he': 1.0955564988535116e-07,
#   'uk': 5.791659714304842e-05,
#   'uz': 4.243714712970359e-09,
#   'hr': 7.861437438805297e-07,
#   'hi': 0.0021281815133988857,
#   'sl': 1.969054210348986e-06,
#   'ko': 0.0014289134414866567,
#   'ml': 0.02035759948194027,
#   'lv': 6.887578933856275e-07,
#   'fi': 0.00010746530460892245,
#   'bo': 2.5974766231229296e-06,
#   'km': 0.00015682584489695728,
#   'jw': 0.002786291064694524,
#   'mi': 3.220932194381021e-05,
#   'ro': 5.45840994163882e-05,
#   'es': 0.00017421130905859172,
#   'fo': 4.3680105932253355e-07,
#   'eu': 2.6443634837391983e-08,
#   'ln': 1.320248177449912e-08,
#   'tl': 0.000498055131174624,
#   'ta': 0.9531129002571106,
#   'bs': 1.812703054326903e-08,
#   'ar': 0.000345461507095024,
#   'hy': 4.691617405683246e-08,
#   'yo': 6.901442247908562e-06,
#   'oc': 9.401624652127794e-07,
#   'gl': 4.532495040621143e-06,
#   'sw': 7.151686986617278e-06,
#   'si': 0.0003394678933545947})

# %% [markdown]
# From above, we can see the probability of each language being the spoken language. English has the highest probability of 98.5%, therefore it is the spoken language in the audio file.

# %% [markdown]
# Next, we can move on to transcription.

# %% [markdown]
# **Transcription**

# %%
transcription = model_m.transcribe(file_path, fp16 = False)['text']

# %%
transcription
# Out:
# ' எல்லா recomprob ம맛다면 நாங்கள் 사람ூர் легூர்வு விரும்பி இருக்கும். கருத்துக் குண்டுப்பா больை பின்னு பிரிமை. பெரிவாநிங்கள் முண்பிதான வாடிக்கைனிdy tonight நாங்கள் பெரிவாநிக்கு.. தீட்டர் இவன் பாட்டிட்டு மருந்துயில், உ கது ப மற்றும் பேர்,'

# %% [markdown]
# From the transcription above, we can see our Speech-To-Text system works very well, it transcribed our audio perfectly.

# %% [markdown]
# As an adition, we can translate our audio file to another language.

# %% [markdown]
# **Translation**

# %% [markdown]
# We would translate our audio file to Spanish, by setting language='es'.

# %%
translation = model_m.transcribe(file_path, language = 'english', fp16 = False)['text']

# %%
translation
# Out:
# ' Hello everyone, we are selected in the university. I am very proud of this. This is our first victory.'

# %% [markdown]
# Our audio file can be translated to other languages as well.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# We have been able to create a Speech-To-Text application using an ASR (Automatic Speech Recognition) system, Whisper. Speech-To-Text has a variety of use cases which include transcribing audio recordings, dictation, voice commands, online search, enhanced customer service etc.
